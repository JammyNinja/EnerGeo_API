# %% [markdown]
# # Imports

# %%
import os
import pandas as pd

# %%
#constants
filename = "df_fuel_ckan.csv"
path_to_data = os.path.join("..", "data")

elements = ["fire", "water", "air", "earth"]
element_mappings = {
    "BIOMASS" : "fire",
    "NUCLEAR" : "fire",
    "SOLAR" : "fire",
    "FOSSIL OIL" : "earth",
    "FOSSIL HARD COAL" : "earth",
    "FOSSIL GAS" : "earth",
    "HYDRO PUMPED STORAGE" : "water",
    "HYDRO RUN-OF-RIVER AND POUNDAGE" : "water",
    "WIND ONSHORE" : "air",
    "WIND OFFSHORE" : "air",
}

# %%
! ls {path_to_data}
# Out:
# cached_live_response.json  gridwatch.csv	   test_current.json
# df_fuel_ckan.csv	   sample_geo_api.json
# geo			   sample_historical.json

# %%
def get_df_from_csv(filename = "df_fuel_ckan.csv"):
    filepath = os.path.join(path_to_data, filename)
    return pd.read_csv(filepath)
    
def preprocess_df(df):
    #convert to datetime for groupby
    df['DATETIME'] = pd.to_datetime(df.DATETIME)

    #select only relevant columns
    sources_list = ['GAS', 'COAL', 'NUCLEAR', 'WIND', 'HYDRO','SOLAR','BIOMASS']#, 'IMPORTS', 'OTHER']
    df = df.set_index("DATETIME")[sources_list]

    rename_dict = {}
    for column in df.columns:
        for source, element in element_mappings.items():
            if column in source:
                rename_dict[column] = f"{column}_{element}"
                
    df = df.rename(columns=rename_dict)
    return df
# Out:
#                            GAS_earth  COAL_earth  NUCLEAR_fire  WIND_air  \
# DATETIME
# 2009-01-01 00:00:00+00:00     8336.0     15035.0        7099.0     279.0
# 2009-01-01 00:30:00+00:00     8456.0     15093.0        7087.0     258.0
# 2009-01-01 01:00:00+00:00     8419.0     15082.0        7074.0     232.0
# 2009-01-01 01:30:00+00:00     8276.0     15022.0        7064.0     214.0
# 2009-01-01 02:00:00+00:00     8247.0     14986.0        7051.0     197.0
# ...                              ...         ...           ...       ...
# 2024-06-26 09:00:00+00:00     8110.0         0.0        5251.0    3147.0
# 2024-06-26 09:30:00+00:00     7836.0         0.0        5251.0    3280.0
# 2024-06-26 10:00:00+00:00     7292.0         0.0        5257.0    3541.0
# 2024-06-26 10:30:00+00:00        0.0         0.0           0.0     655.0
# 2024-06-26 11:00:00+00:00        0.0         0.0           0.0     690.0
#
#                            HYDRO_water  SOLAR_fire  BIOMASS_fire
# DATETIME
# 2009-01-01 00:00:00+00:00        246.0         0.0           0.0
# 2009-01-01 00:30:00+00:00        245.0         0.0           0.0
# 2009-01-01 01:00:00+00:00        246.0         0.0           0.0
# 2009-01-01 01:30:00+00:00        246.0         0.0           0.0
# 2009-01-01 02:00:00+00:00        246.0         0.0           0.0
# ...                                ...         ...           ...
# 2024-06-26 09:00:00+00:00        139.0      7366.0        1653.0
# 2024-06-26 09:30:00+00:00         74.0      8169.0        1651.0
# 2024-06-26 10:00:00+00:00         71.0      8861.0        1653.0
# 2024-06-26 10:30:00+00:00          0.0      9368.0           0.0
# 2024-06-26 11:00:00+00:00          0.0      9710.0           0.0
#
# [271463 rows x 7 columns]

# %%
"""
#goals
 "2009": {
    "fire": {
      "sources": [
        {
          "name": "BIOMASS",
          "value": 1292.0
        },
        {
          "name": "SOLAR",
          "value": 8429.0
        },
"""
# Out:
# '\n#goals\n "2009": {\n    "fire": {\n      "sources": [\n        {\n          "name": "BIOMASS",\n          "value": 1292.0\n        },\n        {\n          "name": "SOLAR",\n          "value": 8429.0\n        },\n'

# %%
def build_historical_output(df):
    yearly_df = df.groupby(df.index.year).sum()
    
    output = {}

    for year in yearly_df.index:
        year_data = {}
        for element in elements:
            elem_sources = [col for col in yearly_df if col.endswith(element)]
            sources = []
            for source in elem_sources:
                name = source.split('_')[0]
                value = yearly_df.loc[year][source]
                sources.append({"name" : name , "value" : value})
            year_data[element] = {"sources" : sources}
        output[year] = year_data
        
    return output
# build_output(hist_df)

# %%
def get_historical_output():
    hist_df = preprocess_df(get_df_from_csv())
    hist_out = build_historical_output(hist_df)

    return hist_out
get_historical_output()
# Out:
# {2009: {'fire': {'sources': [{'name': 'NUCLEAR',
#      'value': np.float64(130004163.0)},
#     {'name': 'SOLAR', 'value': np.float64(0.0)},
#     {'name': 'BIOMASS', 'value': np.float64(0.0)}]},
#   'water': {'sources': [{'name': 'HYDRO', 'value': np.float64(7116428.0)}]},
#   'air': {'sources': [{'name': 'WIND', 'value': np.float64(8314691.0)}]},
#   'earth': {'sources': [{'name': 'GAS', 'value': np.float64(294830710.0)},
#     {'name': 'COAL', 'value': np.float64(197612320.0)}]}},
#  2010: {'fire': {'sources': [{'name': 'NUCLEAR',
#      'value': np.float64(117022087.0)},
#     {'name': 'SOLAR', 'value': np.float64(0.0)},
#     {'name': 'BIOMASS', 'value': np.float64(0.0)}]},
#   'water': {'sources': [{'name': 'HYDRO', 'value': np.float64(4276624.0)}]},
#   'air': {'sources': [{'name': 'WIND', 'value': np.float64(9209664.0)}]},
#   'earth': {'sources': [{'name': 'GAS', 'value': np.float64(314185467.0)},
#     {'name': 'COAL', 'value': np.float64(205679693.0)}]}},
#  2011: {'fire': {'sources': [{'name': 'NUCLEAR',
#      'value': np.float64(129542230.0)},
#     {'name': 'SOLAR', 'value': np.float64(0.0)},
#     {'name': 'BIOMASS', 'value': np.float64(0.0)}]},
#   'water': {'sources': [{'name': 'HYDRO', 'value': np.float64(7390411.0)}]},
#   'air': {'sources': [{'name': 'WIND', 'value': np.float64(23822447.0)}]},
#   'earth': {'sources': [{'name': 'GAS', 'value': np.float64(254084595.0)},
#     {'name': 'COAL', 'value': np.float64(206790037.0)}]}},
#  2012: {'fire': {'sources': [{'name': 'NUCLEAR',
#      'value': np.float64(132031585.0)},
#     {'name': 'SOLAR', 'value': np.float64(0.0)},
#     {'name': 'BIOMASS', 'value': np.float64(0.0)}]},
#   'water': {'sources': [{'name': 'HYDRO', 'value': np.float64(6549376.0)}]},
#   'air': {'sources': [{'name': 'WIND', 'value': np.float64(31082343.0)}]},
#   'earth': {'sources': [{'name': 'GAS', 'value': np.float64(166155999.0)},
#     {'name': 'COAL', 'value': np.float64(274341576.0)}]}},
#  2013: {'fire': {'sources': [{'name': 'NUCLEAR',
#      'value': np.float64(131896478.0)},
#     {'name': 'SOLAR', 'value': np.float64(4006687.0)},
#     {'name': 'BIOMASS', 'value': np.float64(0.0)}]},
#   'water': {'sources': [{'name': 'HYDRO', 'value': np.float64(5828794.0)}]},
#   'air': {'sources': [{'name': 'WIND', 'value': np.float64(42727551.0)}]},
#   'earth': {'sources': [{'name': 'GAS', 'value': np.float64(160275317.0)},
#     {'name': 'COAL', 'value': np.float64(251536710.0)}]}},
#  2014: {'fire': {'sources': [{'name': 'NUCLEAR',
#      'value': np.float64(119543486.0)},
#     {'name': 'SOLAR', 'value': np.float64(7639621.0)},
#     {'name': 'BIOMASS', 'value': np.float64(0.0)}]},
#   'water': {'sources': [{'name': 'HYDRO', 'value': np.float64(7849088.0)}]},
#   'air': {'sources': [{'name': 'WIND', 'value': np.float64(50858635.0)}]},
#   'earth': {'sources': [{'name': 'GAS', 'value': np.float64(173253017.0)},
#     {'name': 'COAL', 'value': np.float64(193360504.0)}]}},
#  2015: {'fire': {'sources': [{'name': 'NUCLEAR',
#      'value': np.float64(131415297.0)},
#     {'name': 'SOLAR', 'value': np.float64(14211751.0)},
#     {'name': 'BIOMASS', 'value': np.float64(0.0)}]},
#   'water': {'sources': [{'name': 'HYDRO', 'value': np.float64(8188877.0)}]},
#   'air': {'sources': [{'name': 'WIND', 'value': np.float64(63359149.0)}]},
#   'earth': {'sources': [{'name': 'GAS', 'value': np.float64(168615077.0)},
#     {'name': 'COAL', 'value': np.float64(148996757.0)}]}},
#  2016: {'fire': {'sources': [{'name': 'NUCLEAR',
#      'value': np.float64(133602115.0)},
#     {'name': 'SOLAR', 'value': np.float64(19745937.0)},
#     {'name': 'BIOMASS', 'value': np.float64(0.0)}]},
#   'water': {'sources': [{'name': 'HYDRO', 'value': np.float64(6758571.0)}]},
#   'air': {'sources': [{'name': 'WIND', 'value': np.float64(60627090.0)}]},
#   'earth': {'sources': [{'name': 'GAS', 'value': np.float64(254508438.0)},
#     {'name': 'COAL', 'value': np.float64(56043955.0)}]}},
#  2017: {'fire': {'sources': [{'name': 'NUCLEAR',
#      'value': np.float64(131113353.0)},
#     {'name': 'SOLAR', 'value': np.float64(20618807.0)},
#     {'name': 'BIOMASS', 'value': np.float64(4445182.0)}]},
#   'water': {'sources': [{'name': 'HYDRO', 'value': np.float64(7921093.0)}]},
#   'air': {'sources': [{'name': 'WIND', 'value': np.float64(88436947.0)}]},
#   'earth': {'sources': [{'name': 'GAS', 'value': np.float64(238455979.0)},
#     {'name': 'COAL', 'value': np.float64(41223600.0)}]}},
#  2018: {'fire': {'sources': [{'name': 'NUCLEAR',
#      'value': np.float64(121304330.0)},
#     {'name': 'SOLAR', 'value': np.float64(22480104.0)},
#     {'name': 'BIOMASS', 'value': np.float64(32204097.0)}]},
#   'water': {'sources': [{'name': 'HYDRO', 'value': np.float64(6410131.0)}]},
#   'air': {'sources': [{'name': 'WIND', 'value': np.float64(102486628.0)}]},
#   'earth': {'sources': [{'name': 'GAS', 'value': np.float64(230471284.0)},
#     {'name': 'COAL', 'value': np.float64(30798777.0)}]}},
#  2019: {'fire': {'sources': [{'name': 'NUCLEAR',
#      'value': np.float64(105533424.0)},
#     {'name': 'SOLAR', 'value': np.float64(22708502.0)},
#     {'name': 'BIOMASS', 'value': np.float64(34405960.0)}]},
#   'water': {'sources': [{'name': 'HYDRO', 'value': np.float64(7148614.0)}]},
#   'air': {'sources': [{'name': 'WIND', 'value': np.float64(116872316.0)}]},
#   'earth': {'sources': [{'name': 'GAS', 'value': np.float64(229139877.0)},
#     {'name': 'COAL', 'value': np.float64(11873793.0)}]}},
#  2020: {'fire': {'sources': [{'name': 'NUCLEAR',
#      'value': np.float64(94813600.0)},
#     {'name': 'SOLAR', 'value': np.float64(23842242.0)},
#     {'name': 'BIOMASS', 'value': np.float64(35960541.0)}]},
#   'water': {'sources': [{'name': 'HYDRO', 'value': np.float64(8620858.0)}]},
#   'air': {'sources': [{'name': 'WIND', 'value': np.float64(136601969.0)}]},
#   'earth': {'sources': [{'name': 'GAS', 'value': np.float64(190188797.0)},
#     {'name': 'COAL', 'value': np.float64(8764658.0)}]}},
#  2021: {'fire': {'sources': [{'name': 'NUCLEAR',
#      'value': np.float64(86833822.0)},
#     {'name': 'SOLAR', 'value': np.float64(23251430.0)},
#     {'name': 'BIOMASS', 'value': np.float64(38035177.0)}]},
#   'water': {'sources': [{'name': 'HYDRO', 'value': np.float64(6474433.0)}]},
#   'air': {'sources': [{'name': 'WIND', 'value': np.float64(124411040.0)}]},
#   'earth': {'sources': [{'name': 'GAS', 'value': np.float64(214491971.0)},
#     {'name': 'COAL', 'value': np.float64(9946735.0)}]}},
#  2022: {'fire': {'sources': [{'name': 'NUCLEAR',
#      'value': np.float64(89455703.0)},
#     {'name': 'SOLAR', 'value': np.float64(26135960.0)},
#     {'name': 'BIOMASS', 'value': np.float64(29940566.0)}]},
#   'water': {'sources': [{'name': 'HYDRO', 'value': np.float64(6657301.0)}]},
#   'air': {'sources': [{'name': 'WIND', 'value': np.float64(154503403.0)}]},
#   'earth': {'sources': [{'name': 'GAS', 'value': np.float64(222458061.0)},
#     {'name': 'COAL', 'value': np.float64(8545472.0)}]}},
#  2023: {'fire': {'sources': [{'name': 'NUCLEAR',
#      'value': np.float64(76595848.0)},
#     {'name': 'SOLAR', 'value': np.float64(26535809.0)},
#     {'name': 'BIOMASS', 'value': np.float64(26717395.0)}]},
#   'water': {'sources': [{'name': 'HYDRO', 'value': np.float64(6496111.0)}]},
#   'air': {'sources': [{'name': 'WIND', 'value': np.float64(157967159.0)}]},
#   'earth': {'sources': [{'name': 'GAS', 'value': np.float64(172926423.0)},
#     {'name': 'COAL', 'value': np.float64(5527392.0)}]}},
#  2024: {'fire': {'sources': [{'name': 'NUCLEAR',
#      'value': np.float64(36082492.0)},
#     {'name': 'SOLAR', 'value': np.float64(13989401.0)},
#     {'name': 'BIOMASS', 'value': np.float64(17522657.0)}]},
#   'water': {'sources': [{'name': 'HYDRO', 'value': np.float64(3759239.0)}]},
#   'air': {'sources': [{'name': 'WIND', 'value': np.float64(82857511.0)}]},
#   'earth': {'sources': [{'name': 'GAS', 'value': np.float64(69261379.0)},
#     {'name': 'COAL', 'value': np.float64(2668233.0)}]}}}

# %% [markdown]
# ## investigate percentage columns

# %%
perc_cols = [col for col in hist_df.columns if col.endswith("perc")]
perc_df = hist_df[perc_cols]

try_cols = ["LOW_CARBON_perc", "RENEWABLE_perc", "FOSSIL_perc"]
perc_df.loc[:,try_cols]#.sum(axis=1)
#up to solar adds up to 100
# Out:
#                            LOW_CARBON_perc  RENEWABLE_perc  FOSSIL_perc
# DATETIME
# 2009-01-01 00:00:00+00:00             22.8             1.6         69.8
# 2009-01-01 00:30:00+00:00             22.6             1.5         70.0
# 2009-01-01 01:00:00+00:00             22.5             1.4         70.1
# 2009-01-01 01:30:00+00:00             22.6             1.4         70.1
# 2009-01-01 02:00:00+00:00             22.7             1.3         70.2
# ...                                    ...             ...          ...
# 2024-06-26 09:00:00+00:00             54.0            32.8         24.9
# 2024-06-26 09:30:00+00:00             55.3            34.6         23.5
# 2024-06-26 10:00:00+00:00             57.4            36.9         21.6
# 2024-06-26 10:30:00+00:00            100.0           100.0          0.0
# 2024-06-26 11:00:00+00:00            100.0           100.0          0.0
#
# [271463 rows x 3 columns]
